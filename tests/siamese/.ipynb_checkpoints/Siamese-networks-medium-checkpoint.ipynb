# %% [markdown]
# # One Shot Learning with Siamese Networks
#
# This is the jupyter notebook that accompanies

# %% [markdown]
# ## Imports
# All the imports are defined here

# %%
# %matplotlib inline
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# %% [markdown]
# ## Helper functions
# Set of helper functions

# %%
def imshow(img,text,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %% [markdown]
# ## Configuration Class
# A simple class to manage configuration

# %%
import os

# %%
class Config():
    training_dir = "./train/"
    testing_dir = "./test/"
    train_batch_size = 64
    train_number_epochs = 2000

# %% [markdown]
# ## Custom Dataset Class
# This dataset generates a pair of images. 0 for geniune pair and 1 for imposter pair

# %%
class SiameseNetworkDataset(Dataset):
    
    def __init__(self,imageFolderDataset,transform=None,should_invert=True):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        self.should_invert = should_invert
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)
        #we need to make sure approx 50% of images are in the same class
        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                #keep looping till the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1]==img1_tuple[1]:
                    break
        else:
            img1_tuple = random.choice(self.imageFolderDataset.imgs)

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %% [markdown]
# ## Using Image Folder Dataset

# %%
folder_dataset = dset.ImageFolder(root=Config.training_dir)

# %%
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transforms.Compose([transforms.Scale((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %% [markdown]
# ## Visualising some of the data
# The top row and the bottom row of any column is one pair. The 0s and 1s correspond to the column of the image.
# 0 indiciates dissimilar, and 1 indicates similar.

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated), 'text')
print(example_batch[2].numpy())
# Out:
# [[ 1.]
#  [ 1.]
#  [ 1.]
#  [ 1.]
#  [ 0.]
#  [ 0.]
#  [ 1.]
#  [ 1.]]
# Process Process-8:
# Process Process-1:
# Process Process-6:
# Process Process-2:
# Process Process-5:
# Process Process-3:
# Process Process-7:
# Process Process-4:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nishant/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/nishant/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/nishant/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/nishant/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nishant/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/nishant/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/home/nishant/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
# KeyboardInterrupt
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/nishant/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/nishant/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %% [markdown]
# ## Neural Net Definition
# We will use a standard convolutional neural network

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(1, 4, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(4),
            nn.Dropout2d(p=.2),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(4, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),
            nn.Dropout2d(p=.2),

            nn.ReflectionPad2d(1),
            nn.Conv2d(8, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),
            nn.Dropout2d(p=.2),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(8, 16, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(16),
            nn.Dropout2d(p=.2),
        )

        self.fc1 = nn.Sequential(
            nn.Linear(16*100*100, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 5))

    def forward_once(self, x):
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %% [markdown]
# ## Contrastive Loss

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ## Training Time!

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = 0.001 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %%
for epoch in range(0,Config.train_number_epochs):
    for i, data in enumerate(train_dataloader,0):
        img0, img1 , label = data
        img0, img1 , label = Variable(img0).cuda(), Variable(img1).cuda() , Variable(label).cuda()
        output1,output2 = net(img0,img1)
        optimizer.zero_grad()
        loss_contrastive = criterion(output1,output2,label)
        loss_contrastive.backward()
        optimizer.step()
        if i %10 == 0 :
            print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.data[0]))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.data[0])
show_plot(counter,loss_history)
# Out:
# Epoch number 0
#  Current loss 1.6852672100067139
#
# Epoch number 1
#  Current loss 1.143250823020935
#
# Epoch number 2
#  Current loss 1.439818024635315
#
# Epoch number 3
#  Current loss 1.4302685260772705
#
# Epoch number 4
#  Current loss 1.8788113594055176
#
# Epoch number 5
#  Current loss 1.1168612241744995
#
# Epoch number 6
#  Current loss 1.148118495941162
#
# Epoch number 7
#  Current loss 1.2371524572372437
#
# Epoch number 8
#  Current loss 1.1643539667129517
#
# Epoch number 9
#  Current loss 1.0112206935882568
#
# Epoch number 10
#  Current loss 1.120400071144104
#
# Epoch number 11
#  Current loss 1.861061930656433
#
# Epoch number 12
#  Current loss 1.2051955461502075
#
# Epoch number 13
#  Current loss 1.9685617685317993
#
# Epoch number 14
#  Current loss 1.1542567014694214
#
# Epoch number 15
#  Current loss 1.277054786682129
#
# Epoch number 16
#  Current loss 1.0742870569229126
#
# Epoch number 17
#  Current loss 1.1558287143707275
#
# Epoch number 18
#  Current loss 1.1586933135986328
#
# Epoch number 19
#  Current loss 1.3267619609832764
#
# Epoch number 20
#  Current loss 1.1594123840332031
#
# Epoch number 21
#  Current loss 1.281165361404419
#
# Epoch number 22
#  Current loss 1.1540087461471558
#
# Epoch number 23
#  Current loss 1.1876487731933594
#
# Epoch number 24
#  Current loss 1.328428864479065
#
# Epoch number 25
#  Current loss 1.2889597415924072
#
# Epoch number 26
#  Current loss 1.1863197088241577
#
# Epoch number 27
#  Current loss 1.1308848857879639
#
# Epoch number 28
#  Current loss 1.2747687101364136
#
# Epoch number 29
#  Current loss 1.0049331188201904
#
# Epoch number 30
#  Current loss 1.1823797225952148
#
# Epoch number 31
#  Current loss 1.0335218906402588
#
# Epoch number 32
#  Current loss 1.4456175565719604
#
# Epoch number 33
#  Current loss 0.849973201751709
#
# Epoch number 34
#  Current loss 1.3514548540115356
#
# Epoch number 35
#  Current loss 1.0566447973251343
#
# Epoch number 36
#  Current loss 0.995758593082428
#
# Epoch number 37
#  Current loss 1.1544634103775024
#
# Epoch number 38
#  Current loss 1.2294983863830566
#
# Epoch number 39
#  Current loss 1.1108448505401611
#
# Epoch number 40
#  Current loss 1.0261430740356445
#
# Epoch number 41
#  Current loss 1.2739849090576172
#
# Epoch number 42
#  Current loss 1.0909702777862549
#
# Epoch number 43
#  Current loss 1.0360623598098755
#
# Epoch number 44
#  Current loss 1.049665927886963
#
# Epoch number 45
#  Current loss 1.083871841430664
#
# Epoch number 46
#  Current loss 1.2291173934936523
#
# Epoch number 47
#  Current loss 0.802936315536499
#
# Epoch number 48
#  Current loss 1.1224238872528076
#
# Epoch number 49
#  Current loss 0.834595263004303
#
# Epoch number 50
#  Current loss 1.1350327730178833
#
# Epoch number 51
#  Current loss 1.141930103302002
#
# Epoch number 52
#  Current loss 0.8401663899421692
#
# Epoch number 53
#  Current loss 0.9862759113311768
#
# Epoch number 54
#  Current loss 0.7458497881889343
#
# Epoch number 55
#  Current loss 0.8787585496902466
#
# Epoch number 56
#  Current loss 1.036819577217102
#
# Epoch number 57
#  Current loss 0.8972892761230469
#
# Epoch number 58
#  Current loss 0.8299897313117981
#
# Epoch number 59
#  Current loss 0.9327709674835205
#
# Epoch number 60
#  Current loss 0.8301311731338501
#
# Epoch number 61
#  Current loss 0.8844801187515259
#
# Epoch number 62
#  Current loss 0.7177907824516296
#
# Epoch number 63
#  Current loss 1.1610947847366333
#
# Epoch number 64
#  Current loss 0.7866827249526978
#
# Epoch number 65
#  Current loss 0.8708221912384033
#
# Epoch number 66
#  Current loss 0.9930021166801453
#
# Epoch number 67
#  Current loss 0.8750500082969666
#
# Epoch number 68
#  Current loss 0.9872616529464722
#
# Epoch number 69
#  Current loss 0.6769360899925232
#
# Epoch number 70
#  Current loss 1.019736886024475
#
# Epoch number 71
#  Current loss 0.7216023206710815
#
# Epoch number 72
#  Current loss 1.275531530380249
#
# Epoch number 73
#  Current loss 0.6682339906692505
#
# Epoch number 74
#  Current loss 0.9522668123245239
#
# Epoch number 75
#  Current loss 0.7497389912605286
#
# Epoch number 76
#  Current loss 1.0055516958236694
#
# Epoch number 77
#  Current loss 1.1514995098114014
#
# Epoch number 78
#  Current loss 0.7563353180885315
#
# Epoch number 79
#  Current loss 0.9483534693717957
#
# Epoch number 80
#  Current loss 0.8051496744155884
#
# Epoch number 81
#  Current loss 0.8397205471992493
#
# Epoch number 82
#  Current loss 0.7451462745666504
#
# Epoch number 83
#  Current loss 0.8298810124397278
#
# Epoch number 84
#  Current loss 0.6261897087097168
#
# Epoch number 85
#  Current loss 0.6542595624923706
#
# Epoch number 86
#  Current loss 0.6996273994445801
#
# Epoch number 87
#  Current loss 0.6921947002410889
#
# Epoch number 88
#  Current loss 0.8648136258125305
#
# Epoch number 89
#  Current loss 0.7899280786514282
#
# Epoch number 90
#  Current loss 0.7928640842437744
#
# Epoch number 91
#  Current loss 1.0863934755325317
#
# Epoch number 92
#  Current loss 0.6144481897354126
#
# Epoch number 93
#  Current loss 0.7032337188720703
#
# Epoch number 94
#  Current loss 0.7736864686012268
#
# Epoch number 95
#  Current loss 0.7062594890594482
#
# Epoch number 96
#  Current loss 0.615041196346283
#
# Epoch number 97
#  Current loss 0.7660323977470398
#
# Epoch number 98
#  Current loss 0.8062067627906799
#
# Epoch number 99
#  Current loss 0.6384389400482178
#
# Epoch number 100
#  Current loss 0.7656245231628418
#
# Epoch number 101
#  Current loss 0.7924220561981201
#
# Epoch number 102
#  Current loss 0.5958995819091797
#
# Epoch number 103
#  Current loss 0.8504636287689209
#
# Epoch number 104
#  Current loss 0.7220208048820496
#
# Epoch number 105
#  Current loss 0.7342591285705566
#
# Epoch number 106
#  Current loss 0.866146981716156
#
# Epoch number 107
#  Current loss 0.6618677973747253
#
# Epoch number 108
#  Current loss 0.8229054808616638
#
# Epoch number 109
#  Current loss 0.7893176674842834
#
# Epoch number 110
#  Current loss 0.8637559413909912
#
# Epoch number 111
#  Current loss 0.6659088730812073
#
# Epoch number 112
#  Current loss 0.7352920174598694
#
# Epoch number 113
#  Current loss 0.5367740988731384
#
# Epoch number 114
#  Current loss 0.6674150824546814
#
# Epoch number 115
#  Current loss 0.503725528717041
#
# Epoch number 116
#  Current loss 0.5782693028450012
#
# Epoch number 117
#  Current loss 0.7185271978378296
#
# Epoch number 118
#  Current loss 0.6836923956871033
#
# Epoch number 119
#  Current loss 0.6529192328453064
#
# Epoch number 120
#  Current loss 0.41742080450057983
#
# Epoch number 121
#  Current loss 0.8820743560791016
#
# Epoch number 122
#  Current loss 0.6126260161399841
#
# Epoch number 123
#  Current loss 0.5940477848052979
#
# Epoch number 124
#  Current loss 0.7495760321617126
#
# Epoch number 125
#  Current loss 0.7272452116012573
#
# Epoch number 126
#  Current loss 0.4891951084136963
#
# Epoch number 127
#  Current loss 0.5543347001075745
#
# Epoch number 128
#  Current loss 0.634238064289093
#
# Epoch number 129
#  Current loss 0.6650463342666626
#
# Epoch number 130
#  Current loss 0.5606659054756165
#
# Epoch number 131
#  Current loss 0.5421320199966431
#
# Epoch number 132
#  Current loss 0.45328259468078613
#
# Epoch number 133
#  Current loss 0.6152954697608948
#
# Epoch number 134
#  Current loss 0.6052696704864502
#
# Epoch number 135
#  Current loss 0.6143044829368591
#
# Epoch number 136
#  Current loss 0.5504089593887329
#
# Epoch number 137
#  Current loss 0.5068275928497314
#
# Epoch number 138
#  Current loss 0.541877031326294
#
# Epoch number 139
#  Current loss 0.532277524471283
#
# Epoch number 140
#  Current loss 0.54229736328125
#
# Epoch number 141
#  Current loss 0.5944651961326599
#
# Epoch number 142
#  Current loss 0.6781452298164368
#
# Epoch number 143
#  Current loss 0.6260508894920349
#
# Epoch number 144
#  Current loss 0.5205651521682739
#
# Epoch number 145
#  Current loss 0.4643876850605011
#
# Epoch number 146
#  Current loss 0.5008962154388428
#
# Epoch number 147
#  Current loss 0.6538602113723755
#
# Epoch number 148
#  Current loss 0.3801833391189575
#
# Epoch number 149
#  Current loss 0.49500566720962524
#
# Epoch number 150
#  Current loss 0.5844398140907288
#
# Epoch number 151
#  Current loss 0.5065668225288391
#
# Epoch number 152
#  Current loss 0.5396990180015564
#
# Epoch number 153
#  Current loss 0.6866790652275085
#
# Epoch number 154
#  Current loss 0.5144581198692322
#
# Epoch number 155
#  Current loss 0.6045117974281311
#
# Epoch number 156
#  Current loss 0.7345322966575623
#
# Epoch number 157
#  Current loss 0.4161481261253357
#
# Epoch number 158
#  Current loss 0.6351225972175598
#
# Epoch number 159
#  Current loss 0.5494018793106079
#
# Epoch number 160
#  Current loss 0.5571750998497009
#
# Epoch number 161
#  Current loss 0.473854124546051
#
# Epoch number 162
#  Current loss 0.31342625617980957
#
# Epoch number 163
#  Current loss 0.5223767757415771
# Epoch number 164
#  Current loss 0.43155336380004883
#
# Epoch number 165
#  Current loss 0.5891835689544678
#
# Epoch number 166
#  Current loss 0.3987928628921509
#
# Epoch number 167
#  Current loss 0.5180873870849609
#
# Epoch number 168
#  Current loss 0.4915969967842102
#
# Epoch number 169
#  Current loss 0.5082591772079468
#
# Epoch number 170
#  Current loss 0.4846254587173462
#
# Epoch number 171
#  Current loss 0.705294668674469
#
# Epoch number 172
#  Current loss 0.6320339441299438
#
# Epoch number 173
#  Current loss 0.5106093287467957
#
# Epoch number 174
#  Current loss 0.6519243717193604
#
# Epoch number 175
#  Current loss 0.653467059135437
#
# Epoch number 176
#  Current loss 0.503363847732544
#
# Epoch number 177
#  Current loss 0.4398261606693268
#
# Epoch number 178
#  Current loss 0.38625621795654297
#
# Epoch number 179
#  Current loss 0.6010830402374268
#
# Epoch number 180
#  Current loss 0.6738556027412415
#
# Epoch number 181
#  Current loss 0.46863552927970886
#
# Epoch number 182
#  Current loss 0.5072543025016785
#
# Epoch number 183
#  Current loss 0.4320754408836365
#
# Epoch number 184
#  Current loss 0.3830416798591614
#
# Epoch number 185
#  Current loss 0.422573983669281
#
# Epoch number 186
#  Current loss 0.3429378867149353
#
# Epoch number 187
#  Current loss 0.5091990232467651
#
# Epoch number 188
#  Current loss 0.38650116324424744
#
# Epoch number 189
#  Current loss 0.6426401138305664
#
# Epoch number 190
#  Current loss 0.7654820084571838
#
# Epoch number 191
#  Current loss 0.5614705085754395
#
# Epoch number 192
#  Current loss 0.41099563241004944
#
# Epoch number 193
#  Current loss 0.48875197768211365
#
# Epoch number 194
#  Current loss 0.5513713955879211
#
# Epoch number 195
#  Current loss 0.5801779627799988
#
# Epoch number 196
#  Current loss 0.5379133224487305
#
# Epoch number 197
#  Current loss 0.38283178210258484
#
# Epoch number 198
#  Current loss 0.4470495581626892
#
# Epoch number 199
#  Current loss 0.4232150912284851
#
# Epoch number 200
#  Current loss 0.39343592524528503
#
# Epoch number 201
#  Current loss 0.49190303683280945
#
# Epoch number 202
#  Current loss 0.5002173781394958
#
# Epoch number 203
#  Current loss 0.6158919930458069
#
# Epoch number 204
#  Current loss 0.4312629699707031
#
# Epoch number 205
#  Current loss 0.31809690594673157
#
# Epoch number 206
#  Current loss 0.4438697397708893
#
# Epoch number 207
#  Current loss 0.36341872811317444
#
# Epoch number 208
#  Current loss 0.5541211366653442
#
# Epoch number 209
#  Current loss 0.33354946970939636
#
# Epoch number 210
#  Current loss 0.4248218536376953
#
# Epoch number 211
#  Current loss 0.4214058220386505
#
# Epoch number 212
#  Current loss 0.4224030673503876
#
# Epoch number 213
#  Current loss 0.30167561769485474
#
# Epoch number 214
#  Current loss 0.5296269655227661
#
# Epoch number 215
#  Current loss 0.3220970630645752
#
# Epoch number 216
#  Current loss 0.48759838938713074
#
# Epoch number 217
#  Current loss 0.42653995752334595
#
# Epoch number 218
#  Current loss 0.5268179774284363
#
# Epoch number 219
#  Current loss 0.5915621519088745
#
# Epoch number 220
#  Current loss 0.4565899968147278
#
# Epoch number 221
#  Current loss 0.5085219144821167
#
# Epoch number 222
#  Current loss 0.4200620651245117
#
# Epoch number 223
#  Current loss 0.5609041452407837
#
# Epoch number 224
#  Current loss 0.3253469467163086
#
# Epoch number 225
#  Current loss 0.4621899127960205
#
# Epoch number 226
#  Current loss 0.4551239609718323
#
# Epoch number 227
#  Current loss 0.5025336146354675
#
# Epoch number 228
#  Current loss 0.45696374773979187
#
# Epoch number 229
#  Current loss 0.3895622789859772
#
# Epoch number 230
#  Current loss 0.37973853945732117
#
# Epoch number 231
#  Current loss 0.3305308520793915
#
# Epoch number 232
#  Current loss 0.3029579520225525
#
# Epoch number 233
#  Current loss 0.35298028588294983
#
# Epoch number 234
#  Current loss 0.4744464159011841
#
# Epoch number 235
#  Current loss 0.476637065410614
#
# Epoch number 236
#  Current loss 0.3984900712966919
#
# Epoch number 237
#  Current loss 0.3716573417186737
#
# Epoch number 238
#  Current loss 0.2596934735774994
#
# Epoch number 239
#  Current loss 0.33261996507644653
#
# Epoch number 240
#  Current loss 0.356611430644989
#
# Epoch number 241
#  Current loss 0.3789849579334259
#
# Epoch number 242
#  Current loss 0.30357688665390015
#
# Epoch number 243
#  Current loss 0.3965073227882385
#
# Epoch number 244
#  Current loss 0.4752649664878845
#
# Epoch number 245
#  Current loss 0.43964630365371704
#
# Epoch number 246
#  Current loss 0.35222309827804565
#
# Epoch number 247
#  Current loss 0.41754403710365295
#
# Epoch number 248
#  Current loss 0.38249531388282776
#
# Epoch number 249
#  Current loss 0.45965376496315
#
# Epoch number 250
#  Current loss 0.41760000586509705
#
# Epoch number 251
#  Current loss 0.41321179270744324
#
# Epoch number 252
#  Current loss 0.3090619444847107
#
# Epoch number 253
#  Current loss 0.4199351370334625
#
# Epoch number 254
#  Current loss 0.3516155779361725
#
# Epoch number 255
#  Current loss 0.44102343916893005
#
# Epoch number 256
#  Current loss 0.3510558009147644
#
# Epoch number 257
#  Current loss 0.4337114989757538
#
# Epoch number 258
#  Current loss 0.5521836876869202
#
# Epoch number 259
#  Current loss 0.5458354949951172
#
# Epoch number 260
#  Current loss 0.2894102931022644
#
# Epoch number 261
#  Current loss 0.2622186541557312
#
# Epoch number 262
#  Current loss 0.41265273094177246
#
# Epoch number 263
#  Current loss 0.23970215022563934
#
# Epoch number 264
#  Current loss 0.2578360438346863
#
# Epoch number 265
#  Current loss 0.4317091703414917
#
# Epoch number 266
#  Current loss 0.28386956453323364
#
# Epoch number 267
#  Current loss 0.3142920434474945
#
# Epoch number 268
#  Current loss 0.33488893508911133
#
# Epoch number 269
#  Current loss 0.4135643243789673
#
# Epoch number 270
#  Current loss 0.22285299003124237
#
# Epoch number 271
#  Current loss 0.3325105905532837
#
# Epoch number 272
#  Current loss 0.38396793603897095
#
# Epoch number 273
#  Current loss 0.4815984070301056
#
# Epoch number 274
#  Current loss 0.30888956785202026
#
# Epoch number 275
#  Current loss 0.2593344748020172
#
# Epoch number 276
#  Current loss 0.2726290225982666
#
# Epoch number 277
#  Current loss 0.3934253752231598
#
# Epoch number 278
#  Current loss 0.3796311616897583
#
# Epoch number 279
#  Current loss 0.44380858540534973
#
# Epoch number 280
#  Current loss 0.3134993314743042
#
# Epoch number 281
#  Current loss 0.24182629585266113
#
# Epoch number 282
#  Current loss 0.35834094882011414
#
# Epoch number 283
#  Current loss 0.3335762619972229
#
# Epoch number 284
#  Current loss 0.29328668117523193
#
# Epoch number 285
#  Current loss 0.2838364541530609
#
# Epoch number 286
#  Current loss 0.43949460983276367
#
# Epoch number 287
#  Current loss 0.3689030408859253
#
# Epoch number 288
#  Current loss 0.3928029239177704
#
# Epoch number 289
#  Current loss 0.405942440032959
#
# Epoch number 290
#  Current loss 0.2558990716934204
#
# Epoch number 291
#  Current loss 0.31683674454689026
#
# Epoch number 292
#  Current loss 0.36300763487815857
#
# Epoch number 293
#  Current loss 0.25153645873069763
#
# Epoch number 294
#  Current loss 0.2552667260169983
#
# Epoch number 295
#  Current loss 0.3650813102722168
#
# Epoch number 296
#  Current loss 0.21292395889759064
#
# Epoch number 297
#  Current loss 0.3175109326839447
#
# Epoch number 298
#  Current loss 0.2307453453540802
#
# Epoch number 299
#  Current loss 0.4554781913757324
#
# Epoch number 300
#  Current loss 0.2580135464668274
#
# Epoch number 301
#  Current loss 0.30540013313293457
#
# Epoch number 302
#  Current loss 0.4194783866405487
#
# Epoch number 303
#  Current loss 0.33284780383110046
#
# Epoch number 304
#  Current loss 0.31438302993774414
#
# Epoch number 305
#  Current loss 0.2672658860683441
#
# Epoch number 306
#  Current loss 0.22194571793079376
#
# Epoch number 307
#  Current loss 0.23732472956180573
#
# Epoch number 308
#  Current loss 0.460557758808136
#
# Epoch number 309
#  Current loss 0.23088110983371735
#
# Epoch number 310
#  Current loss 0.24660328030586243
#
# Epoch number 311
#  Current loss 0.4355805516242981
#
# Epoch number 312
#  Current loss 0.35834991931915283
#
# Epoch number 313
#  Current loss 0.23225004971027374
#
# Epoch number 314
#  Current loss 0.2817935049533844
#
# Epoch number 315
#  Current loss 0.26364484429359436
#
# Epoch number 316
#  Current loss 0.3200204074382782
#
# Epoch number 317
#  Current loss 0.3125799298286438
#
# Epoch number 318
#  Current loss 0.2804265022277832
#
# Epoch number 319
#  Current loss 0.3639545738697052
#
# Epoch number 320
#  Current loss 0.26448431611061096
#
# Epoch number 321
#  Current loss 0.36208921670913696
#
# Epoch number 322
#  Current loss 0.3289136290550232
#
# Epoch number 323
#  Current loss 0.2816372811794281
# Epoch number 324
#  Current loss 0.32849135994911194
#
# Epoch number 325
#  Current loss 0.3386853039264679
#
# Epoch number 326
#  Current loss 0.3017917275428772
#
# Epoch number 327
#  Current loss 0.22209443151950836
#
# Epoch number 328
#  Current loss 0.30101069808006287
#
# Epoch number 329
#  Current loss 0.489711731672287
#
# Epoch number 330
#  Current loss 0.18395580351352692
#
# Epoch number 331
#  Current loss 0.28786855936050415
#
# Epoch number 332
#  Current loss 0.30350440740585327
#
# Epoch number 333
#  Current loss 0.21310269832611084
#
# Epoch number 334
#  Current loss 0.24319423735141754
#
# Epoch number 335
#  Current loss 0.3888775706291199
#
# Epoch number 336
#  Current loss 0.37866660952568054
#
# Epoch number 337
#  Current loss 0.2924520969390869
#
# Epoch number 338
#  Current loss 0.19657382369041443
#
# Epoch number 339
#  Current loss 0.5014908909797668
#
# Epoch number 340
#  Current loss 0.2838904857635498
#
# Epoch number 341
#  Current loss 0.21304331719875336
#
# Epoch number 342
#  Current loss 0.2591620981693268
#
# Epoch number 343
#  Current loss 0.2131674438714981
#
# Epoch number 344
#  Current loss 0.39203977584838867
#
# Epoch number 345
#  Current loss 0.3523203134536743
#
# Epoch number 346
#  Current loss 0.29289689660072327
#
# Epoch number 347
#  Current loss 0.28647157549858093
#
# Epoch number 348
#  Current loss 0.4378097355365753
#
# Epoch number 349
#  Current loss 0.2956709861755371
#
# Epoch number 350
#  Current loss 0.1970565766096115
#
# Epoch number 351
#  Current loss 0.2892155647277832
#
# Epoch number 352
#  Current loss 0.2229994833469391
#
# Epoch number 353
#  Current loss 0.5822730660438538
#
# Epoch number 354
#  Current loss 0.24508383870124817
#
# Epoch number 355
#  Current loss 0.368264377117157
#
# Epoch number 356
#  Current loss 0.25295811891555786
#
# Epoch number 357
#  Current loss 0.2854546010494232
#
# Epoch number 358
#  Current loss 0.2522490322589874
#
# Epoch number 359
#  Current loss 0.22252534329891205
#
# Epoch number 360
#  Current loss 0.3498481214046478
#
# Epoch number 361
#  Current loss 0.2594336271286011
#
# Epoch number 362
#  Current loss 0.26560306549072266
#
# Epoch number 363
#  Current loss 0.19944238662719727
#
# Epoch number 364
#  Current loss 0.3227666914463043
#
# Epoch number 365
#  Current loss 0.26020166277885437
#
# Epoch number 366
#  Current loss 0.1499522179365158
#
# Epoch number 367
#  Current loss 0.33282819390296936
#
# Epoch number 368
#  Current loss 0.301321417093277
#
# Epoch number 369
#  Current loss 0.2628042697906494
#
# Epoch number 370
#  Current loss 0.20688863098621368
#
# Epoch number 371
#  Current loss 0.22484424710273743
#
# Epoch number 372
#  Current loss 0.2220798134803772
#
# Epoch number 373
#  Current loss 0.2793002724647522
#
# Epoch number 374
#  Current loss 0.3309270143508911
#
# Epoch number 375
#  Current loss 0.3128814101219177
#
# Epoch number 376
#  Current loss 0.27386483550071716
#
# Epoch number 377
#  Current loss 0.3261565566062927
#
# Epoch number 378
#  Current loss 0.23015502095222473
#
# Epoch number 379
#  Current loss 0.24625375866889954
#
# Epoch number 380
#  Current loss 0.2612552344799042
#
# Epoch number 381
#  Current loss 0.26627111434936523
#
# Epoch number 382
#  Current loss 0.29246729612350464
#
# Epoch number 383
#  Current loss 0.27927812933921814
#
# Epoch number 384
#  Current loss 0.3417007327079773
#
# Epoch number 385
#  Current loss 0.2880729138851166
#
# Epoch number 386
#  Current loss 0.20975361764431
#
# Epoch number 387
#  Current loss 0.32485154271125793
#
# Epoch number 388
#  Current loss 0.28017207980155945
#
# Epoch number 389
#  Current loss 0.30429765582084656
#
# Epoch number 390
#  Current loss 0.2801031470298767
#
# Epoch number 391
#  Current loss 0.27807265520095825
#
# Epoch number 392
#  Current loss 0.2284923940896988
#
# Epoch number 393
#  Current loss 0.22719290852546692
#
# Epoch number 394
#  Current loss 0.19612209498882294
#
# Epoch number 395
#  Current loss 0.2540554702281952
#
# Epoch number 396
#  Current loss 0.28410619497299194
#
# Epoch number 397
#  Current loss 0.2923511266708374
#
# Epoch number 398
#  Current loss 0.3061133623123169
#
# Epoch number 399
#  Current loss 0.31314074993133545
#
# Epoch number 400
#  Current loss 0.37317779660224915
#
# Epoch number 401
#  Current loss 0.25370869040489197
#
# Epoch number 402
#  Current loss 0.29874947667121887
#
# Epoch number 403
#  Current loss 0.309363454580307
#
# Epoch number 404
#  Current loss 0.2678305208683014
#
# Epoch number 405
#  Current loss 0.2373303920030594
#
# Epoch number 406
#  Current loss 0.23302994668483734
#
# Epoch number 407
#  Current loss 0.30988213419914246
#
# Epoch number 408
#  Current loss 0.3314506411552429
#
# Epoch number 409
#  Current loss 0.2850070595741272
#
# Epoch number 410
#  Current loss 0.22648614645004272
#
# Epoch number 411
#  Current loss 0.25019946694374084
#
# Epoch number 412
#  Current loss 0.2043321430683136
#
# Epoch number 413
#  Current loss 0.22484645247459412
#
# Epoch number 414
#  Current loss 0.2953149378299713
#
# Epoch number 415
#  Current loss 0.3197166621685028
#
# Epoch number 416
#  Current loss 0.26735541224479675
#
# Epoch number 417
#  Current loss 0.3065212666988373
#
# Epoch number 418
#  Current loss 0.25891393423080444
#
# Epoch number 419
#  Current loss 0.30530911684036255
#
# Epoch number 420
#  Current loss 0.2660416066646576
#
# Epoch number 421
#  Current loss 0.22321978211402893
#
# Epoch number 422
#  Current loss 0.26016390323638916
#
# Epoch number 423
#  Current loss 0.2871599495410919
#
# Epoch number 424
#  Current loss 0.2994793653488159
#
# Epoch number 425
#  Current loss 0.32343536615371704
#
# Epoch number 426
#  Current loss 0.2680763006210327
#
# Epoch number 427
#  Current loss 0.2103479951620102
#
# Epoch number 428
#  Current loss 0.27498194575309753
#
# Epoch number 429
#  Current loss 0.21396026015281677
#
# Epoch number 430
#  Current loss 0.16555698215961456
#
# Epoch number 431
#  Current loss 0.19913405179977417
#
# Epoch number 432
#  Current loss 0.25572821497917175
#
# Epoch number 433
#  Current loss 0.2433430403470993
#
# Epoch number 434
#  Current loss 0.241108238697052
#
# Epoch number 435
#  Current loss 0.2969399392604828
#
# Epoch number 436
#  Current loss 0.2532113790512085
#
# Epoch number 437
#  Current loss 0.26620131731033325
#
# Epoch number 438
#  Current loss 0.20020487904548645
#
# Epoch number 439
#  Current loss 0.309880793094635
#
# Epoch number 440
#  Current loss 0.35599055886268616
#
# Epoch number 441
#  Current loss 0.18729865550994873
#
# Epoch number 442
#  Current loss 0.23589427769184113
#
# Epoch number 443
#  Current loss 0.21292446553707123
#
# Epoch number 444
#  Current loss 0.24526697397232056
#
# Epoch number 445
#  Current loss 0.2973335385322571
#
# Epoch number 446
#  Current loss 0.1594187319278717
#
# Epoch number 447
#  Current loss 0.21957515180110931
#
# Epoch number 448
#  Current loss 0.32228565216064453
#
# Epoch number 449
#  Current loss 0.1506989449262619
#
# Epoch number 450
#  Current loss 0.23317602276802063
#
# Epoch number 451
#  Current loss 0.20513348281383514
#
# Epoch number 452
#  Current loss 0.19584935903549194
#
# Epoch number 453
#  Current loss 0.22254149615764618
#
# Epoch number 454
#  Current loss 0.20241162180900574
#
# Epoch number 455
#  Current loss 0.18071714043617249
#
# Epoch number 456
#  Current loss 0.346097469329834
#
# Epoch number 457
#  Current loss 0.27080899477005005
#
# Epoch number 458
#  Current loss 0.3121049702167511
#
# Epoch number 459
#  Current loss 0.28969621658325195
#
# Epoch number 460
#  Current loss 0.2883175313472748
#
# Epoch number 461
#  Current loss 0.2599300742149353
#
# Epoch number 462
#  Current loss 0.21314960718154907
#
# Epoch number 463
#  Current loss 0.1595676839351654
#
# Epoch number 464
#  Current loss 0.23747774958610535
#
# Epoch number 465
#  Current loss 0.20915086567401886
#
# Epoch number 466
#  Current loss 0.15755926072597504
#
# Epoch number 467
#  Current loss 0.27484411001205444
#
# Epoch number 468
#  Current loss 0.3230326771736145
#
# Epoch number 469
#  Current loss 0.22869247198104858
#
# Epoch number 470
#  Current loss 0.24109941720962524
#
# Epoch number 471
#  Current loss 0.33320701122283936
#
# Epoch number 472
#  Current loss 0.2018446922302246
#
# Epoch number 473
#  Current loss 0.24438172578811646
#
# Epoch number 474
#  Current loss 0.376828670501709
#
# Epoch number 475
#  Current loss 0.2270803600549698
#
# Epoch number 476
#  Current loss 0.22847022116184235
#
# Epoch number 477
#  Current loss 0.3667895495891571
#
# Epoch number 478
#  Current loss 0.2514108419418335
#
# Epoch number 479
#  Current loss 0.2892090976238251
#
# Epoch number 480
#  Current loss 0.3690360188484192
#
# Epoch number 481
#  Current loss 0.3518831133842468
#
# Epoch number 482
#  Current loss 0.15159258246421814
#
# Epoch number 483
#  Current loss 0.26314467191696167
# Epoch number 484
#  Current loss 0.23858562111854553
#
# Epoch number 485
#  Current loss 0.1867135614156723
#
# Epoch number 486
#  Current loss 0.24833978712558746
#
# Epoch number 487
#  Current loss 0.3254666030406952
#
# Epoch number 488
#  Current loss 0.2055448591709137
#
# Epoch number 489
#  Current loss 0.14522969722747803
#
# Epoch number 490
#  Current loss 0.17469464242458344
#
# Epoch number 491
#  Current loss 0.30473461747169495
#
# Epoch number 492
#  Current loss 0.19300901889801025
#
# Epoch number 493
#  Current loss 0.18742284178733826
#
# Epoch number 494
#  Current loss 0.20575149357318878
#
# Epoch number 495
#  Current loss 0.2154569774866104
#
# Epoch number 496
#  Current loss 0.2080642729997635
#
# Epoch number 497
#  Current loss 0.273532509803772
#
# Epoch number 498
#  Current loss 0.21003581583499908
#
# Epoch number 499
#  Current loss 0.2699143886566162
#
# Epoch number 500
#  Current loss 0.33250078558921814
#
# Epoch number 501
#  Current loss 0.19629929959774017
#
# Epoch number 502
#  Current loss 0.15742413699626923
#
# Epoch number 503
#  Current loss 0.18622130155563354
#
# Epoch number 504
#  Current loss 0.22151854634284973
#
# Epoch number 505
#  Current loss 0.2442171424627304
#
# Epoch number 506
#  Current loss 0.13127316534519196
#
# Epoch number 507
#  Current loss 0.1665840595960617
#
# Epoch number 508
#  Current loss 0.1330101042985916
#
# Epoch number 509
#  Current loss 0.22737325727939606
#
# Epoch number 510
#  Current loss 0.21403926610946655
#
# Epoch number 511
#  Current loss 0.23657555878162384
#
# Epoch number 512
#  Current loss 0.13592946529388428
#
# Epoch number 513
#  Current loss 0.20072412490844727
#
# Epoch number 514
#  Current loss 0.2196049690246582
#
# Epoch number 515
#  Current loss 0.26198071241378784
#
# Epoch number 516
#  Current loss 0.3589130938053131
#
# Epoch number 517
#  Current loss 0.2992538809776306
#
# Epoch number 518
#  Current loss 0.2656235694885254
#
# Epoch number 519
#  Current loss 0.11993758380413055
#
# Epoch number 520
#  Current loss 0.25845766067504883
#
# Epoch number 521
#  Current loss 0.1704305112361908
#
# Epoch number 522
#  Current loss 0.1625392884016037
#
# Epoch number 523
#  Current loss 0.2327926903963089
#
# Epoch number 524
#  Current loss 0.20801356434822083
#
# Epoch number 525
#  Current loss 0.19798977673053741
#
# Epoch number 526
#  Current loss 0.2594422399997711
#
# Epoch number 527
#  Current loss 0.19673150777816772
#
# Epoch number 528
#  Current loss 0.194014310836792
#
# Epoch number 529
#  Current loss 0.2114315927028656
#
# Epoch number 530
#  Current loss 0.18223555386066437
#
# Epoch number 531
#  Current loss 0.20344863831996918
#
# Epoch number 532
#  Current loss 0.24462702870368958
#
# Epoch number 533
#  Current loss 0.1650223433971405
#
# Epoch number 534
#  Current loss 0.18761564791202545
#
# Epoch number 535
#  Current loss 0.1692655086517334
#
# Epoch number 536
#  Current loss 0.21548724174499512
#
# Epoch number 537
#  Current loss 0.21648845076560974
#
# Epoch number 538
#  Current loss 0.19108782708644867
#
# Epoch number 539
#  Current loss 0.20476417243480682
#
# Epoch number 540
#  Current loss 0.257844477891922
#
# Epoch number 541
#  Current loss 0.17006182670593262
#
# Epoch number 542
#  Current loss 0.3901214003562927
#
# Epoch number 543
#  Current loss 0.30669891834259033
#
# Epoch number 544
#  Current loss 0.217503160238266
#
# Epoch number 545
#  Current loss 0.2118808925151825
#
# Epoch number 546
#  Current loss 0.25984054803848267
#
# Epoch number 547
#  Current loss 0.1659611314535141
#
# Epoch number 548
#  Current loss 0.31768500804901123
#
# Epoch number 549
#  Current loss 0.3203801214694977
#
# Epoch number 550
#  Current loss 0.25920677185058594
#
# Epoch number 551
#  Current loss 0.2098819762468338
#
# Epoch number 552
#  Current loss 0.16989654302597046
#
# Epoch number 553
#  Current loss 0.2687221169471741
#
# Epoch number 554
#  Current loss 0.16247259080410004
#
# Epoch number 555
#  Current loss 0.25770583748817444
#
# Epoch number 556
#  Current loss 0.3095235526561737
#
# Epoch number 557
#  Current loss 0.23583391308784485
#
# Epoch number 558
#  Current loss 0.2657111883163452
#
# Epoch number 559
#  Current loss 0.18191595375537872
#
# Epoch number 560
#  Current loss 0.22052113711833954
#
# Epoch number 561
#  Current loss 0.2307906150817871
#
# Epoch number 562
#  Current loss 0.22696611285209656
#
# Epoch number 563
#  Current loss 0.15169227123260498
#
# Epoch number 564
#  Current loss 0.22125566005706787
#
# Epoch number 565
#  Current loss 0.19754360616207123
#
# Epoch number 566
#  Current loss 0.2904506325721741
#
# Epoch number 567
#  Current loss 0.19464129209518433
#
# Epoch number 568
#  Current loss 0.25067639350891113
#
# Epoch number 569
#  Current loss 0.17712123692035675
#
# Epoch number 570
#  Current loss 0.22423893213272095
#
# Epoch number 571
#  Current loss 0.09944766759872437
#
# Epoch number 572
#  Current loss 0.28241166472435
#
# Epoch number 573
#  Current loss 0.1779516488313675
#
# Epoch number 574
#  Current loss 0.27642884850502014
#
# Epoch number 575
#  Current loss 0.23068900406360626
#
# Epoch number 576
#  Current loss 0.14235827326774597
#
# Epoch number 577
#  Current loss 0.2717324197292328
#
# Epoch number 578
#  Current loss 0.3063907325267792
#
# Epoch number 579
#  Current loss 0.1898786425590515
#
# Epoch number 580
#  Current loss 0.3508792519569397
#
# Epoch number 581
#  Current loss 0.24774305522441864
#
# Epoch number 582
#  Current loss 0.15435726940631866
#
# Epoch number 583
#  Current loss 0.20854921638965607
#
# Epoch number 584
#  Current loss 0.17862729728221893
#
# Epoch number 585
#  Current loss 0.27542704343795776
#
# Epoch number 586
#  Current loss 0.2832704186439514
#
# Epoch number 587
#  Current loss 0.15227116644382477
#
# Epoch number 588
#  Current loss 0.3576773703098297
#
# Epoch number 589
#  Current loss 0.16584865748882294
#
# Epoch number 590
#  Current loss 0.142425537109375
#
# Epoch number 591
#  Current loss 0.32477864623069763
#
# Epoch number 592
#  Current loss 0.18682652711868286
#
# Epoch number 593
#  Current loss 0.224481463432312
#
# Epoch number 594
#  Current loss 0.1695537567138672
#
# Epoch number 595
#  Current loss 0.15713901817798615
#
# Epoch number 596
#  Current loss 0.2698584794998169
#
# Epoch number 597
#  Current loss 0.20538045465946198
#
# Epoch number 598
#  Current loss 0.268157958984375
#
# Epoch number 599
#  Current loss 0.30170348286628723
#
# Epoch number 600
#  Current loss 0.15027105808258057
#
# Epoch number 601
#  Current loss 0.2452300488948822
#
# Epoch number 602
#  Current loss 0.1602967381477356
#
# Epoch number 603
#  Current loss 0.3120732605457306
#
# Epoch number 604
#  Current loss 0.19852705299854279
#
# Epoch number 605
#  Current loss 0.166474387049675
#
# Epoch number 606
#  Current loss 0.19668453931808472
#
# Epoch number 607
#  Current loss 0.27245256304740906
#
# Epoch number 608
#  Current loss 0.18915808200836182
#
# Epoch number 609
#  Current loss 0.22250932455062866
#
# Epoch number 610
#  Current loss 0.17256560921669006
#
# Epoch number 611
#  Current loss 0.12824799120426178
#
# Epoch number 612
#  Current loss 0.2660532593727112
#
# Epoch number 613
#  Current loss 0.2661340832710266
#
# Epoch number 614
#  Current loss 0.2775769829750061
#
# Epoch number 615
#  Current loss 0.18572604656219482
#
# Epoch number 616
#  Current loss 0.17773769795894623
#
# Epoch number 617
#  Current loss 0.17667575180530548
#
# Epoch number 618
#  Current loss 0.22831664979457855
#
# Epoch number 619
#  Current loss 0.4135902523994446
#
# Epoch number 620
#  Current loss 0.22281819581985474
#
# Epoch number 621
#  Current loss 0.13024085760116577
#
# Epoch number 622
#  Current loss 0.38054248690605164
#
# Epoch number 623
#  Current loss 0.26116347312927246
#
# Epoch number 624
#  Current loss 0.1047348752617836
#
# Epoch number 625
#  Current loss 0.20744773745536804
#
# Epoch number 626
#  Current loss 0.2313157021999359
#
# Epoch number 627
#  Current loss 0.17599859833717346
#
# Epoch number 628
#  Current loss 0.22482019662857056
#
# Epoch number 629
#  Current loss 0.19437865912914276
#
# Epoch number 630
#  Current loss 0.24097082018852234
#
# Epoch number 631
#  Current loss 0.20113377273082733
#
# Epoch number 632
#  Current loss 0.2482108622789383
#
# Epoch number 633
#  Current loss 0.14705048501491547
#
# Epoch number 634
#  Current loss 0.17828185856342316
#
# Epoch number 635
#  Current loss 0.11789066344499588
#
# Epoch number 636
#  Current loss 0.18430720269680023
#
# Epoch number 637
#  Current loss 0.285251259803772
#
# Epoch number 638
#  Current loss 0.19438853859901428
#
# Epoch number 639
#  Current loss 0.13688668608665466
#
# Epoch number 640
#  Current loss 0.17239385843276978
#
# Epoch number 641
#  Current loss 0.1822427660226822
#
# Epoch number 642
#  Current loss 0.15549899637699127
# Epoch number 643
#  Current loss 0.1524229347705841
#
# Epoch number 644
#  Current loss 0.2440386563539505
#
# Epoch number 645
#  Current loss 0.12917795777320862
#
# Epoch number 646
#  Current loss 0.19186235964298248
#
# Epoch number 647
#  Current loss 0.17348995804786682
#
# Epoch number 648
#  Current loss 0.15178216993808746
#
# Epoch number 649
#  Current loss 0.2402985841035843
#
# Epoch number 650
#  Current loss 0.1514500230550766
#
# Epoch number 651
#  Current loss 0.17831984162330627
#
# Epoch number 652
#  Current loss 0.17066346108913422
#
# Epoch number 653
#  Current loss 0.22135962545871735
#
# Epoch number 654
#  Current loss 0.16102805733680725
#
# Epoch number 655
#  Current loss 0.2614438235759735
#
# Epoch number 656
#  Current loss 0.2308892160654068
#
# Epoch number 657
#  Current loss 0.16277103126049042
#
# Epoch number 658
#  Current loss 0.20961591601371765
#
# Epoch number 659
#  Current loss 0.11941101402044296
#
# Epoch number 660
#  Current loss 0.20220623910427094
#
# Epoch number 661
#  Current loss 0.21084800362586975
#
# Epoch number 662
#  Current loss 0.1688375174999237
#
# Epoch number 663
#  Current loss 0.14850887656211853
#
# Epoch number 664
#  Current loss 0.16619054973125458
#
# Epoch number 665
#  Current loss 0.2426055669784546
#
# Epoch number 666
#  Current loss 0.19647906720638275
#
# Epoch number 667
#  Current loss 0.17873260378837585
#
# Epoch number 668
#  Current loss 0.2555283308029175
#
# Epoch number 669
#  Current loss 0.21697190403938293
#
# Epoch number 670
#  Current loss 0.233426034450531
#
# Epoch number 671
#  Current loss 0.29792919754981995
#
# Epoch number 672
#  Current loss 0.1914825141429901
#
# Epoch number 673
#  Current loss 0.22910213470458984
#
# Epoch number 674
#  Current loss 0.15268199145793915
#
# Epoch number 675
#  Current loss 0.13574017584323883
#
# Epoch number 676
#  Current loss 0.15313492715358734
#
# Epoch number 677
#  Current loss 0.10010259598493576
#
# Epoch number 678
#  Current loss 0.12866221368312836
#
# Epoch number 679
#  Current loss 0.08772061765193939
#
# Epoch number 680
#  Current loss 0.14093375205993652
#
# Epoch number 681
#  Current loss 0.1258343905210495
#
# Epoch number 682
#  Current loss 0.21996276080608368
#
# Epoch number 683
#  Current loss 0.17856818437576294
#
# Epoch number 684
#  Current loss 0.16925372183322906
#
# Epoch number 685
#  Current loss 0.13142478466033936
#
# Epoch number 686
#  Current loss 0.2719368636608124
#
# Epoch number 687
#  Current loss 0.23978668451309204
#
# Epoch number 688
#  Current loss 0.15634940564632416
#
# Epoch number 689
#  Current loss 0.30500221252441406
#
# Epoch number 690
#  Current loss 0.1545049399137497
#
# Epoch number 691
#  Current loss 0.19547852873802185
#
# Epoch number 692
#  Current loss 0.17946112155914307
#
# Epoch number 693
#  Current loss 0.2690112590789795
#
# Epoch number 694
#  Current loss 0.16853508353233337
#
# Epoch number 695
#  Current loss 0.21825441718101501
#
# Epoch number 696
#  Current loss 0.19333809614181519
#
# Epoch number 697
#  Current loss 0.17476248741149902
#
# Epoch number 698
#  Current loss 0.18507492542266846
#
# Epoch number 699
#  Current loss 0.09385713189840317
#
# Epoch number 700
#  Current loss 0.2793552875518799
#
# Epoch number 701
#  Current loss 0.19266730546951294
#
# Epoch number 702
#  Current loss 0.21708253026008606
#
# Epoch number 703
#  Current loss 0.16313037276268005
#
# Epoch number 704
#  Current loss 0.2123122215270996
#
# Epoch number 705
#  Current loss 0.27815866470336914
#
# Epoch number 706
#  Current loss 0.13246335089206696
#
# Epoch number 707
#  Current loss 0.14748477935791016
#
# Epoch number 708
#  Current loss 0.20897021889686584
#
# Epoch number 709
#  Current loss 0.16633820533752441
#
# Epoch number 710
#  Current loss 0.19528540968894958
#
# Epoch number 711
#  Current loss 0.2169000208377838
#
# Epoch number 712
#  Current loss 0.11791642010211945
#
# Epoch number 713
#  Current loss 0.1425490528345108
#
# Epoch number 714
#  Current loss 0.2076934576034546
#
# Epoch number 715
#  Current loss 0.15294262766838074
#
# Epoch number 716
#  Current loss 0.1131407842040062
#
# Epoch number 717
#  Current loss 0.22053231298923492
#
# Epoch number 718
#  Current loss 0.10283935815095901
#
# Epoch number 719
#  Current loss 0.14563700556755066
#
# Epoch number 720
#  Current loss 0.1491578221321106
#
# Epoch number 721
#  Current loss 0.13683578372001648
#
# Epoch number 722
#  Current loss 0.16915975511074066
#
# Epoch number 723
#  Current loss 0.16141633689403534
#
# Epoch number 724
#  Current loss 0.3924703598022461
#
# Epoch number 725
#  Current loss 0.14188195765018463
#
# Epoch number 726
#  Current loss 0.1459079533815384
#
# Epoch number 727
#  Current loss 0.15448147058486938
#
# Epoch number 728
#  Current loss 0.22213786840438843
#
# Epoch number 729
#  Current loss 0.15080106258392334
#
# Epoch number 730
#  Current loss 0.11640629172325134
#
# Epoch number 731
#  Current loss 0.08756513893604279
#
# Epoch number 732
#  Current loss 0.16598956286907196
#
# Epoch number 733
#  Current loss 0.20699578523635864
#
# Epoch number 734
#  Current loss 0.34591352939605713
#
# Epoch number 735
#  Current loss 0.15451645851135254
#
# Epoch number 736
#  Current loss 0.2698155343532562
#
# Epoch number 737
#  Current loss 0.224683478474617
#
# Epoch number 738
#  Current loss 0.26810190081596375
#
# Epoch number 739
#  Current loss 0.1364484429359436
#
# Epoch number 740
#  Current loss 0.19739511609077454
#
# Epoch number 741
#  Current loss 0.18977096676826477
#
# Epoch number 742
#  Current loss 0.27542412281036377
#
# Epoch number 743
#  Current loss 0.1695801019668579
#
# Epoch number 744
#  Current loss 0.24632328748703003
#
# Epoch number 745
#  Current loss 0.19166631996631622
#
# Epoch number 746
#  Current loss 0.19363227486610413
#
# Epoch number 747
#  Current loss 0.24507500231266022
#
# Epoch number 748
#  Current loss 0.1439598798751831
#
# Epoch number 749
#  Current loss 0.16971592605113983
#
# Epoch number 750
#  Current loss 0.13810531795024872
#
# Epoch number 751
#  Current loss 0.1559475213289261
#
# Epoch number 752
#  Current loss 0.11120869964361191
#
# Epoch number 753
#  Current loss 0.19285954535007477
#
# Epoch number 754
#  Current loss 0.16404788196086884
#
# Epoch number 755
#  Current loss 0.14723247289657593
#
# Epoch number 756
#  Current loss 0.1867513656616211
#
# Epoch number 757
#  Current loss 0.17338746786117554
#
# Epoch number 758
#  Current loss 0.10994964838027954
#
# Epoch number 759
#  Current loss 0.14714424312114716
#
# Epoch number 760
#  Current loss 0.11407813429832458
#
# Epoch number 761
#  Current loss 0.16753000020980835
#
# Epoch number 762
#  Current loss 0.1774064153432846
#
# Epoch number 763
#  Current loss 0.19365118443965912
#
# Epoch number 764
#  Current loss 0.21081072092056274
#
# Epoch number 765
#  Current loss 0.16283433139324188
#
# Epoch number 766
#  Current loss 0.14220374822616577
#
# Epoch number 767
#  Current loss 0.12968496978282928
#
# Epoch number 768
#  Current loss 0.14388476312160492
#
# Epoch number 769
#  Current loss 0.15541936457157135
#
# Epoch number 770
#  Current loss 0.18635058403015137
#
# Epoch number 771
#  Current loss 0.14629021286964417
#
# Epoch number 772
#  Current loss 0.18658678233623505
#
# Epoch number 773
#  Current loss 0.09951844811439514
#
# Epoch number 774
#  Current loss 0.19174447655677795
#
# Epoch number 775
#  Current loss 0.14787805080413818
#
# Epoch number 776
#  Current loss 0.30086907744407654
#
# Epoch number 777
#  Current loss 0.23263175785541534
#
# Epoch number 778
#  Current loss 0.1589956283569336
#
# Epoch number 779
#  Current loss 0.2702653110027313
#
# Epoch number 780
#  Current loss 0.2248372882604599
#
# Epoch number 781
#  Current loss 0.23598259687423706
#
# Epoch number 782
#  Current loss 0.12894482910633087
#
# Epoch number 783
#  Current loss 0.13948354125022888
#
# Epoch number 784
#  Current loss 0.17413736879825592
#
# Epoch number 785
#  Current loss 0.25647518038749695
#
# Epoch number 786
#  Current loss 0.19457466900348663
#
# Epoch number 787
#  Current loss 0.2233135849237442
#
# Epoch number 788
#  Current loss 0.1674230694770813
#
# Epoch number 789
#  Current loss 0.25957220792770386
#
# Epoch number 790
#  Current loss 0.1821080893278122
#
# Epoch number 791
#  Current loss 0.37943169474601746
#
# Epoch number 792
#  Current loss 0.18457050621509552
#
# Epoch number 793
#  Current loss 0.15533281862735748
#
# Epoch number 794
#  Current loss 0.20434510707855225
#
# Epoch number 795
#  Current loss 0.17647887766361237
#
# Epoch number 796
#  Current loss 0.17138567566871643
#
# Epoch number 797
#  Current loss 0.13657641410827637
#
# Epoch number 798
#  Current loss 0.2519630491733551
#
# Epoch number 799
#  Current loss 0.174189031124115
#
# Epoch number 800
#  Current loss 0.19598273932933807
#
# Epoch number 801
#  Current loss 0.11989612877368927
# Epoch number 802
#  Current loss 0.09408223628997803
#
# Epoch number 803
#  Current loss 0.12273507565259933
#
# Epoch number 804
#  Current loss 0.10650661587715149
#
# Epoch number 805
#  Current loss 0.1382439136505127
#
# Epoch number 806
#  Current loss 0.20668847858905792
#
# Epoch number 807
#  Current loss 0.1546190232038498
#
# Epoch number 808
#  Current loss 0.10563141107559204
#
# Epoch number 809
#  Current loss 0.10447815805673599
#
# Epoch number 810
#  Current loss 0.14526242017745972
#
# Epoch number 811
#  Current loss 0.18051579594612122
#
# Epoch number 812
#  Current loss 0.1292334347963333
#
# Epoch number 813
#  Current loss 0.17749279737472534
#
# Epoch number 814
#  Current loss 0.11635308712720871
#
# Epoch number 815
#  Current loss 0.16024461388587952
#
# Epoch number 816
#  Current loss 0.13690555095672607
#
# Epoch number 817
#  Current loss 0.15753740072250366
#
# Epoch number 818
#  Current loss 0.12381407618522644
#
# Epoch number 819
#  Current loss 0.10635653883218765
#
# Epoch number 820
#  Current loss 0.2194516956806183
#
# Epoch number 821
#  Current loss 0.12429073452949524
#
# Epoch number 822
#  Current loss 0.14085187017917633
#
# Epoch number 823
#  Current loss 0.16475939750671387
#
# Epoch number 824
#  Current loss 0.18895021080970764
#
# Epoch number 825
#  Current loss 0.13446475565433502
#
# Epoch number 826
#  Current loss 0.1581161767244339
#
# Epoch number 827
#  Current loss 0.1739627569913864
#
# Epoch number 828
#  Current loss 0.17983631789684296
#
# Epoch number 829
#  Current loss 0.19630776345729828
#
# Epoch number 830
#  Current loss 0.13921886682510376
#
# Epoch number 831
#  Current loss 0.14024534821510315
#
# Epoch number 832
#  Current loss 0.13233670592308044
#
# Epoch number 833
#  Current loss 0.14799152314662933
#
# Epoch number 834
#  Current loss 0.14595280587673187
#
# Epoch number 835
#  Current loss 0.248503178358078
#
# Epoch number 836
#  Current loss 0.179524227976799
#
# Epoch number 837
#  Current loss 0.14131394028663635
#
# Epoch number 838
#  Current loss 0.17652858793735504
#
# Epoch number 839
#  Current loss 0.09939563274383545
#
# Epoch number 840
#  Current loss 0.1319878250360489
#
# Epoch number 841
#  Current loss 0.14832310378551483
#
# Epoch number 842
#  Current loss 0.1222868338227272
#
# Epoch number 843
#  Current loss 0.18744607269763947
#
# Epoch number 844
#  Current loss 0.25841352343559265
#
# Epoch number 845
#  Current loss 0.25611475110054016
#
# Epoch number 846
#  Current loss 0.2398265153169632
#
# Epoch number 847
#  Current loss 0.24058708548545837
#
# Epoch number 848
#  Current loss 0.14139750599861145
#
# Epoch number 849
#  Current loss 0.12693770229816437
#
# Epoch number 850
#  Current loss 0.15453112125396729
#
# Epoch number 851
#  Current loss 0.12321243435144424
#
# Epoch number 852
#  Current loss 0.15827985107898712
#
# Epoch number 853
#  Current loss 0.15352070331573486
#
# Epoch number 854
#  Current loss 0.08308080583810806
#
# Epoch number 855
#  Current loss 0.16002336144447327
#
# Epoch number 856
#  Current loss 0.09592704474925995
#
# Epoch number 857
#  Current loss 0.13925763964653015
#
# Epoch number 858
#  Current loss 0.17160360515117645
#
# Epoch number 859
#  Current loss 0.18870356678962708
#
# Epoch number 860
#  Current loss 0.11446189880371094
#
# Epoch number 861
#  Current loss 0.2370627373456955
#
# Epoch number 862
#  Current loss 0.10661639273166656
#
# Epoch number 863
#  Current loss 0.13002759218215942
#
# Epoch number 864
#  Current loss 0.11532942205667496
#
# Epoch number 865
#  Current loss 0.23184452950954437
#
# Epoch number 866
#  Current loss 0.09107764810323715
#
# Epoch number 867
#  Current loss 0.1288226693868637
#
# Epoch number 868
#  Current loss 0.12107784301042557
#
# Epoch number 869
#  Current loss 0.12314693629741669
#
# Epoch number 870
#  Current loss 0.20517702400684357
#
# Epoch number 871
#  Current loss 0.10207748413085938
#
# Epoch number 872
#  Current loss 0.1966843456029892
#
# Epoch number 873
#  Current loss 0.08689681440591812
#
# Epoch number 874
#  Current loss 0.08637657761573792
#
# Epoch number 875
#  Current loss 0.1733582764863968
#
# Epoch number 876
#  Current loss 0.16024906933307648
#
# Epoch number 877
#  Current loss 0.09397424012422562
#
# Epoch number 878
#  Current loss 0.13767357170581818
#
# Epoch number 879
#  Current loss 0.13686881959438324
#
# Epoch number 880
#  Current loss 0.09741578996181488
#
# Epoch number 881
#  Current loss 0.1631956696510315
#
# Epoch number 882
#  Current loss 0.1466454267501831
#
# Epoch number 883
#  Current loss 0.08408213406801224
#
# Epoch number 884
#  Current loss 0.176466703414917
#
# Epoch number 885
#  Current loss 0.09490271657705307
#
# Epoch number 886
#  Current loss 0.11385611444711685
#
# Epoch number 887
#  Current loss 0.13710744678974152
#
# Epoch number 888
#  Current loss 0.10664395987987518
#
# Epoch number 889
#  Current loss 0.11086401343345642
#
# Epoch number 890
#  Current loss 0.19361725449562073
#
# Epoch number 891
#  Current loss 0.21861371397972107
#
# Epoch number 892
#  Current loss 0.17093922197818756
#
# Epoch number 893
#  Current loss 0.16137804090976715
#
# Epoch number 894
#  Current loss 0.15219712257385254
#
# Epoch number 895
#  Current loss 0.21319589018821716
#
# Epoch number 896
#  Current loss 0.19921673834323883
#
# Epoch number 897
#  Current loss 0.17815335094928741
#
# Epoch number 898
#  Current loss 0.15533582866191864
#
# Epoch number 899
#  Current loss 0.2937314808368683
#
# Epoch number 900
#  Current loss 0.15563513338565826
#
# Epoch number 901
#  Current loss 0.14698345959186554
#
# Epoch number 902
#  Current loss 0.16211552917957306
#
# Epoch number 903
#  Current loss 0.1457899957895279
#
# Epoch number 904
#  Current loss 0.16833843290805817
#
# Epoch number 905
#  Current loss 0.1811799257993698
#
# Epoch number 906
#  Current loss 0.1549791395664215
#
# Epoch number 907
#  Current loss 0.1489402949810028
#
# Epoch number 908
#  Current loss 0.07446467131376266
#
# Epoch number 909
#  Current loss 0.1632908284664154
#
# Epoch number 910
#  Current loss 0.1321217119693756
#
# Epoch number 911
#  Current loss 0.12831108272075653
#
# Epoch number 912
#  Current loss 0.11928769201040268
#
# Epoch number 913
#  Current loss 0.10234010219573975
#
# Epoch number 914
#  Current loss 0.1616610288619995
#
# Epoch number 915
#  Current loss 0.10237564891576767
#
# Epoch number 916
#  Current loss 0.07075805962085724
#
# Epoch number 917
#  Current loss 0.1030169352889061
#
# Epoch number 918
#  Current loss 0.13850949704647064
#
# Epoch number 919
#  Current loss 0.1734626293182373
#
# Epoch number 920
#  Current loss 0.1595805287361145
#
# Epoch number 921
#  Current loss 0.1686546951532364
#
# Epoch number 922
#  Current loss 0.2002379298210144
#
# Epoch number 923
#  Current loss 0.12383469194173813
#
# Epoch number 924
#  Current loss 0.15389025211334229
#
# Epoch number 925
#  Current loss 0.22683706879615784
#
# Epoch number 926
#  Current loss 0.10643675923347473
#
# Epoch number 927
#  Current loss 0.14117053151130676
#
# Epoch number 928
#  Current loss 0.08795934915542603
#
# Epoch number 929
#  Current loss 0.11315944790840149
#
# Epoch number 930
#  Current loss 0.1273801028728485
#
# Epoch number 931
#  Current loss 0.19343352317810059
#
# Epoch number 932
#  Current loss 0.09832983464002609
#
# Epoch number 933
#  Current loss 0.2135423719882965
#
# Epoch number 934
#  Current loss 0.17681637406349182
#
# Epoch number 935
# ...
#  Current loss 0.024748630821704865
#
# Epoch number 1701
#  Current loss 0.037644293159246445
#
# Epoch number 1702
#  Current loss 0.06120162084698677
#
# Epoch number 1703
#  Current loss 0.06597660481929779
#
# Epoch number 1704
#  Current loss 0.03599847853183746
#
# Epoch number 1705
#  Current loss 0.04090218245983124
#
# Epoch number 1706
#  Current loss 0.06194059178233147
#
# Epoch number 1707
#  Current loss 0.039713818579912186
#
# Epoch number 1708
#  Current loss 0.07216394692659378
#
# Epoch number 1709
#  Current loss 0.062259089201688766
#
# Epoch number 1710
#  Current loss 0.03673237934708595
#
# Epoch number 1711
#  Current loss 0.052446186542510986
#
# Epoch number 1712
#  Current loss 0.05717841535806656
#
# Epoch number 1713
#  Current loss 0.04576333984732628
#
# Epoch number 1714
#  Current loss 0.05218640714883804
#
# Epoch number 1715
#  Current loss 0.0830436497926712
#
# Epoch number 1716
#  Current loss 0.04734482988715172
#
# Epoch number 1717
#  Current loss 0.03818197548389435
#
# Epoch number 1718
#  Current loss 0.028095275163650513
#
# Epoch number 1719
#  Current loss 0.03149714320898056
#
# Epoch number 1720
#  Current loss 0.032396022230386734
#
# Epoch number 1721
#  Current loss 0.028133384883403778
#
# Epoch number 1722
#  Current loss 0.07955783605575562
#
# Epoch number 1723
#  Current loss 0.04752926528453827
#
# Epoch number 1724
#  Current loss 0.023571370169520378
#
# Epoch number 1725
#  Current loss 0.06161273270845413
#
# Epoch number 1726
#  Current loss 0.04337368905544281
#
# Epoch number 1727
#  Current loss 0.04474406689405441
#
# Epoch number 1728
#  Current loss 0.02175775356590748
#
# Epoch number 1729
#  Current loss 0.05316833406686783
#
# Epoch number 1730
#  Current loss 0.028524447232484818
#
# Epoch number 1731
#  Current loss 0.032150767743587494
#
# Epoch number 1732
#  Current loss 0.05123157054185867
#
# Epoch number 1733
#  Current loss 0.0431896410882473
#
# Epoch number 1734
#  Current loss 0.061652928590774536
#
# Epoch number 1735
#  Current loss 0.01700715534389019
#
# Epoch number 1736
#  Current loss 0.05869688093662262
#
# Epoch number 1737
#  Current loss 0.025805145502090454
# Epoch number 1738
#  Current loss 0.03770590201020241
#
# Epoch number 1739
#  Current loss 0.012251099571585655
#
# Epoch number 1740
#  Current loss 0.028246361762285233
#
# Epoch number 1741
#  Current loss 0.0828925222158432
#
# Epoch number 1742
#  Current loss 0.02268471196293831
#
# Epoch number 1743
#  Current loss 0.02918136864900589
#
# Epoch number 1744
#  Current loss 0.03408564254641533
#
# Epoch number 1745
#  Current loss 0.04594380408525467
#
# Epoch number 1746
#  Current loss 0.04717407375574112
#
# Epoch number 1747
#  Current loss 0.04040739685297012
#
# Epoch number 1748
#  Current loss 0.03472648933529854
#
# Epoch number 1749
#  Current loss 0.03878457471728325
#
# Epoch number 1750
#  Current loss 0.025672417134046555
#
# Epoch number 1751
#  Current loss 0.020065590739250183
#
# Epoch number 1752
#  Current loss 0.016763679683208466
#
# Epoch number 1753
#  Current loss 0.018786601722240448
#
# Epoch number 1754
#  Current loss 0.033957552164793015
#
# Epoch number 1755
#  Current loss 0.02516164816915989
#
# Epoch number 1756
#  Current loss 0.023869073018431664
#
# Epoch number 1757
#  Current loss 0.0920814499258995
#
# Epoch number 1758
#  Current loss 0.05059979856014252
#
# Epoch number 1759
#  Current loss 0.024675974622368813
#
# Epoch number 1760
#  Current loss 0.036574698984622955
#
# Epoch number 1761
#  Current loss 0.054032646119594574
#
# Epoch number 1762
#  Current loss 0.018991880118846893
#
# Epoch number 1763
#  Current loss 0.03102199360728264
#
# Epoch number 1764
#  Current loss 0.028251074254512787
#
# Epoch number 1765
#  Current loss 0.02925567515194416
#
# Epoch number 1766
#  Current loss 0.021724557504057884
#
# Epoch number 1767
#  Current loss 0.0402345135807991
#
# Epoch number 1768
#  Current loss 0.02368873544037342
#
# Epoch number 1769
#  Current loss 0.09566877037286758
#
# Epoch number 1770
#  Current loss 0.07024560868740082
#
# Epoch number 1771
#  Current loss 0.016623536124825478
#
# Epoch number 1772
#  Current loss 0.02186957187950611
#
# Epoch number 1773
#  Current loss 0.026537517085671425
#
# Epoch number 1774
#  Current loss 0.021587833762168884
#
# Epoch number 1775
#  Current loss 0.03531090170145035
#
# Epoch number 1776
#  Current loss 0.018428698182106018
#
# Epoch number 1777
#  Current loss 0.036597080528736115
#
# Epoch number 1778
#  Current loss 0.07034754008054733
#
# Epoch number 1779
#  Current loss 0.04245426133275032
#
# Epoch number 1780
#  Current loss 0.04378274455666542
#
# Epoch number 1781
#  Current loss 0.036777958273887634
#
# Epoch number 1782
#  Current loss 0.0691048875451088
#
# Epoch number 1783
#  Current loss 0.043992042541503906
#
# Epoch number 1784
#  Current loss 0.08827459812164307
#
# Epoch number 1785
#  Current loss 0.05848189815878868
#
# Epoch number 1786
#  Current loss 0.04604097828269005
#
# Epoch number 1787
#  Current loss 0.03279581665992737
#
# Epoch number 1788
#  Current loss 0.034764308482408524
#
# Epoch number 1789
#  Current loss 0.025855379179120064
#
# Epoch number 1790
#  Current loss 0.054974883794784546
#
# Epoch number 1791
#  Current loss 0.06629056483507156
#
# Epoch number 1792
#  Current loss 0.02048630453646183
#
# Epoch number 1793
#  Current loss 0.02352941408753395
#
# Epoch number 1794
#  Current loss 0.08445935696363449
#
# Epoch number 1795
#  Current loss 0.1003013476729393
#
# Epoch number 1796
#  Current loss 0.034760989248752594
#
# Epoch number 1797
#  Current loss 0.20483309030532837
#
# Epoch number 1798
#  Current loss 0.054742831736803055
#
# Epoch number 1799
#  Current loss 0.031813979148864746
#
# Epoch number 1800
#  Current loss 0.0261559896171093
#
# Epoch number 1801
#  Current loss 0.041634656488895416
#
# Epoch number 1802
#  Current loss 0.03673109784722328
#
# Epoch number 1803
#  Current loss 0.013690711930394173
#
# Epoch number 1804
#  Current loss 0.02025161124765873
#
# Epoch number 1805
#  Current loss 0.13232076168060303
#
# Epoch number 1806
#  Current loss 0.1046622171998024
#
# Epoch number 1807
#  Current loss 0.011317628435790539
#
# Epoch number 1808
#  Current loss 0.08580575883388519
#
# Epoch number 1809
#  Current loss 0.020334243774414062
#
# Epoch number 1810
#  Current loss 0.03262152895331383
#
# Epoch number 1811
#  Current loss 0.03351447731256485
#
# Epoch number 1812
#  Current loss 0.02930387668311596
#
# Epoch number 1813
#  Current loss 0.024841368198394775
#
# Epoch number 1814
#  Current loss 0.03664225712418556
#
# Epoch number 1815
#  Current loss 0.030500710010528564
#
# Epoch number 1816
#  Current loss 0.02762286551296711
#
# Epoch number 1817
#  Current loss 0.021031469106674194
#
# Epoch number 1818
#  Current loss 0.023229803889989853
#
# Epoch number 1819
#  Current loss 0.01893511787056923
#
# Epoch number 1820
#  Current loss 0.033256255090236664
#
# Epoch number 1821
#  Current loss 0.04988369718194008
#
# Epoch number 1822
#  Current loss 0.026958689093589783
#
# Epoch number 1823
#  Current loss 0.023198332637548447
#
# Epoch number 1824
#  Current loss 0.04969610646367073
#
# Epoch number 1825
#  Current loss 0.034284498542547226
#
# Epoch number 1826
#  Current loss 0.023476753383874893
#
# Epoch number 1827
#  Current loss 0.08589987456798553
#
# Epoch number 1828
#  Current loss 0.05930253490805626
#
# Epoch number 1829
#  Current loss 0.034184157848358154
#
# Epoch number 1830
#  Current loss 0.03910334035754204
#
# Epoch number 1831
#  Current loss 0.03149629756808281
#
# Epoch number 1832
#  Current loss 0.053681179881095886
#
# Epoch number 1833
#  Current loss 0.027901018038392067
#
# Epoch number 1834
#  Current loss 0.03081844560801983
#
# Epoch number 1835
#  Current loss 0.0810571238398552
#
# Epoch number 1836
#  Current loss 0.03688202053308487
#
# Epoch number 1837
#  Current loss 0.050289832055568695
#
# Epoch number 1838
#  Current loss 0.024577058851718903
#
# Epoch number 1839
#  Current loss 0.02189900539815426
#
# Epoch number 1840
#  Current loss 0.02529190666973591
#
# Epoch number 1841
#  Current loss 0.021612830460071564
#
# Epoch number 1842
#  Current loss 0.035401783883571625
#
# Epoch number 1843
#  Current loss 0.06725917756557465
#
# Epoch number 1844
#  Current loss 0.04146227985620499
#
# Epoch number 1845
#  Current loss 0.032475024461746216
#
# Epoch number 1846
#  Current loss 0.03258681669831276
#
# Epoch number 1847
#  Current loss 0.026779264211654663
#
# Epoch number 1848
#  Current loss 0.023885590955615044
#
# Epoch number 1849
#  Current loss 0.020427051931619644
#
# Epoch number 1850
#  Current loss 0.038016170263290405
#
# Epoch number 1851
#  Current loss 0.019618390128016472
#
# Epoch number 1852
#  Current loss 0.016613684594631195
#
# Epoch number 1853
#  Current loss 0.016543110832571983
#
# Epoch number 1854
#  Current loss 0.032488517463207245
#
# Epoch number 1855
#  Current loss 0.0219240952283144
#
# Epoch number 1856
#  Current loss 0.016338380053639412
#
# Epoch number 1857
#  Current loss 0.01903008110821247
#
# Epoch number 1858
#  Current loss 0.02530815824866295
#
# Epoch number 1859
#  Current loss 0.02799711748957634
#
# Epoch number 1860
#  Current loss 0.03434457629919052
#
# Epoch number 1861
#  Current loss 0.06218937039375305
#
# Epoch number 1862
#  Current loss 0.02087467350065708
#
# Epoch number 1863
#  Current loss 0.017911633476614952
#
# Epoch number 1864
#  Current loss 0.030646853148937225
#
# Epoch number 1865
#  Current loss 0.01810341700911522
#
# Epoch number 1866
#  Current loss 0.030434222891926765
#
# Epoch number 1867
#  Current loss 0.03514102101325989
#
# Epoch number 1868
#  Current loss 0.0963502898812294
#
# Epoch number 1869
#  Current loss 0.023899495601654053
#
# Epoch number 1870
#  Current loss 0.03167889639735222
#
# Epoch number 1871
#  Current loss 0.020196355879306793
#
# Epoch number 1872
#  Current loss 0.02627771534025669
#
# Epoch number 1873
#  Current loss 0.06404847651720047
#
# Epoch number 1874
#  Current loss 0.0211836788803339
#
# Epoch number 1875
#  Current loss 0.031932953745126724
#
# Epoch number 1876
#  Current loss 0.04571632668375969
#
# Epoch number 1877
#  Current loss 0.022732244804501534
#
# Epoch number 1878
#  Current loss 0.03159871697425842
#
# Epoch number 1879
#  Current loss 0.022939197719097137
#
# Epoch number 1880
#  Current loss 0.04282546788454056
#
# Epoch number 1881
#  Current loss 0.017972562462091446
#
# Epoch number 1882
#  Current loss 0.02581685781478882
#
# Epoch number 1883
#  Current loss 0.03244832530617714
#
# Epoch number 1884
#  Current loss 0.05375926196575165
#
# Epoch number 1885
#  Current loss 0.029820846393704414
#
# Epoch number 1886
#  Current loss 0.024696962907910347
#
# Epoch number 1887
#  Current loss 0.03585974872112274
#
# Epoch number 1888
#  Current loss 0.048815637826919556
#
# Epoch number 1889
#  Current loss 0.037570685148239136
#
# Epoch number 1890
#  Current loss 0.040486421436071396
#
# Epoch number 1891
#  Current loss 0.02917630597949028
# Epoch number 1892
#  Current loss 0.06997843831777573
#
# Epoch number 1893
#  Current loss 0.027284618467092514
#
# Epoch number 1894
#  Current loss 0.09000035375356674
#
# Epoch number 1895
#  Current loss 0.021844597533345222
#
# Epoch number 1896
#  Current loss 0.04265235736966133
#
# Epoch number 1897
#  Current loss 0.04185200110077858
#
# Epoch number 1898
#  Current loss 0.03339897096157074
#
# Epoch number 1899
#  Current loss 0.04509833827614784
#
# Epoch number 1900
#  Current loss 0.0564199760556221
#
# Epoch number 1901
#  Current loss 0.02864157222211361
#
# Epoch number 1902
#  Current loss 0.031633369624614716
#
# Epoch number 1903
#  Current loss 0.019345678389072418
#
# Epoch number 1904
#  Current loss 0.036655738949775696
#
# Epoch number 1905
#  Current loss 0.02881360985338688
#
# Epoch number 1906
#  Current loss 0.01697111688554287
#
# Epoch number 1907
#  Current loss 0.02177312783896923
#
# Epoch number 1908
#  Current loss 0.022703643888235092
#
# Epoch number 1909
#  Current loss 0.0653146356344223
#
# Epoch number 1910
#  Current loss 0.015452193096280098
#
# Epoch number 1911
#  Current loss 0.0716511681675911
#
# Epoch number 1912
#  Current loss 0.09493105858564377
#
# Epoch number 1913
#  Current loss 0.016996249556541443
#
# Epoch number 1914
#  Current loss 0.030758900567889214
#
# Epoch number 1915
#  Current loss 0.022596022114157677
#
# Epoch number 1916
#  Current loss 0.03051411733031273
#
# Epoch number 1917
#  Current loss 0.018976133316755295
#
# Epoch number 1918
#  Current loss 0.01669052056968212
#
# Epoch number 1919
#  Current loss 0.03234201669692993
#
# Epoch number 1920
#  Current loss 0.025013893842697144
#
# Epoch number 1921
#  Current loss 0.042551472783088684
#
# Epoch number 1922
#  Current loss 0.028803490102291107
#
# Epoch number 1923
#  Current loss 0.02913839742541313
#
# Epoch number 1924
#  Current loss 0.040494248270988464
#
# Epoch number 1925
#  Current loss 0.02724982611835003
#
# Epoch number 1926
#  Current loss 0.022473778575658798
#
# Epoch number 1927
#  Current loss 0.02112741395831108
#
# Epoch number 1928
#  Current loss 0.021918077021837234
#
# Epoch number 1929
#  Current loss 0.036399420350790024
#
# Epoch number 1930
#  Current loss 0.014321232214570045
#
# Epoch number 1931
#  Current loss 0.029341816902160645
#
# Epoch number 1932
#  Current loss 0.030218053609132767
#
# Epoch number 1933
#  Current loss 0.013384413905441761
#
# Epoch number 1934
#  Current loss 0.029902605339884758
#
# Epoch number 1935
#  Current loss 0.031071361154317856
#
# Epoch number 1936
#  Current loss 0.0979318767786026
#
# Epoch number 1937
#  Current loss 0.023213393986225128
#
# Epoch number 1938
#  Current loss 0.036681633442640305
#
# Epoch number 1939
#  Current loss 0.05433746054768562
#
# Epoch number 1940
#  Current loss 0.027269737794995308
#
# Epoch number 1941
#  Current loss 0.03858374431729317
#
# Epoch number 1942
#  Current loss 0.01993357390165329
#
# Epoch number 1943
#  Current loss 0.04158984497189522
#
# Epoch number 1944
#  Current loss 0.08066364377737045
#
# Epoch number 1945
#  Current loss 0.09735673666000366
#
# Epoch number 1946
#  Current loss 0.011850784532725811
#
# Epoch number 1947
#  Current loss 0.03114033304154873
#
# Epoch number 1948
#  Current loss 0.01842438243329525
#
# Epoch number 1949
#  Current loss 0.1072230115532875
#
# Epoch number 1950
#  Current loss 0.008205250836908817
#
# Epoch number 1951
#  Current loss 0.02194336988031864
#
# Epoch number 1952
#  Current loss 0.09898512810468674
#
# Epoch number 1953
#  Current loss 0.04392073675990105
#
# Epoch number 1954
#  Current loss 0.06169842183589935
#
# Epoch number 1955
#  Current loss 0.022669021040201187
#
# Epoch number 1956
#  Current loss 0.0488797090947628
#
# Epoch number 1957
#  Current loss 0.025778908282518387
#
# Epoch number 1958
#  Current loss 0.04162808507680893
#
# Epoch number 1959
#  Current loss 0.03722589462995529
#
# Epoch number 1960
#  Current loss 0.026434922590851784
#
# Epoch number 1961
#  Current loss 0.022983945906162262
#
# Epoch number 1962
#  Current loss 0.026359369978308678
#
# Epoch number 1963
#  Current loss 0.0404796339571476
#
# Epoch number 1964
#  Current loss 0.02498503029346466
#
# Epoch number 1965
#  Current loss 0.03351230546832085
#
# Epoch number 1966
#  Current loss 0.16789527237415314
#
# Epoch number 1967
#  Current loss 0.03694400563836098
#
# Epoch number 1968
#  Current loss 0.026013579219579697
#
# Epoch number 1969
#  Current loss 0.03063146583735943
#
# Epoch number 1970
#  Current loss 0.041106220334768295
#
# Epoch number 1971
#  Current loss 0.02329302206635475
#
# Epoch number 1972
#  Current loss 0.021610289812088013
#
# Epoch number 1973
#  Current loss 0.02561081387102604
#
# Epoch number 1974
#  Current loss 0.018352892249822617
#
# Epoch number 1975
#  Current loss 0.017899733036756516
#
# Epoch number 1976
#  Current loss 0.027476800605654716
#
# Epoch number 1977
#  Current loss 0.041658543050289154
#
# Epoch number 1978
#  Current loss 0.022550860419869423
#
# Epoch number 1979
#  Current loss 0.03107604756951332
#
# Epoch number 1980
#  Current loss 0.04511362314224243
#
# Epoch number 1981
#  Current loss 0.025553233921527863
#
# Epoch number 1982
#  Current loss 0.030937936156988144
#
# Epoch number 1983
#  Current loss 0.04140767455101013
#
# Epoch number 1984
#  Current loss 0.036024559289216995
#
# Epoch number 1985
#  Current loss 0.021783312782645226
#
# Epoch number 1986
#  Current loss 0.021517939865589142
#
# Epoch number 1987
#  Current loss 0.027282994240522385
#
# Epoch number 1988
#  Current loss 0.017841022461652756
#
# Epoch number 1989
#  Current loss 0.05011105164885521
#
# Epoch number 1990
#  Current loss 0.012920837849378586
#
# Epoch number 1991
#  Current loss 0.03134975582361221
#
# Epoch number 1992
#  Current loss 0.07900577038526535
#
# Epoch number 1993
#  Current loss 0.04354901611804962
#
# Epoch number 1994
#  Current loss 0.030768193304538727
#
# Epoch number 1995
#  Current loss 0.017273105680942535
#
# Epoch number 1996
#  Current loss 0.017031004652380943
#
# Epoch number 1997
#  Current loss 0.03141675516963005
#
# Epoch number 1998
#  Current loss 0.026730043813586235
#
# Epoch number 1999
#  Current loss 0.02429172582924366

# %% [markdown]
# ## Some simple testing
# The last 3 subjects were held out from the training, and will be used to test. The Distance between each image pair denotes the degree of similarity the model found between the two images. Less means it found more similar, while higher values indicate it found them to be dissimilar.

# %%
folder_dataset_test = dset.ImageFolder(root=Config.testing_dir)
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transforms.Compose([transforms.Scale((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

test_dataloader = DataLoader(siamese_dataset,num_workers=6,batch_size=1,shuffle=True)
dataiter = iter(test_dataloader)
x0,_,_ = next(dataiter)

for i in range(10):
    _,x1,label2 = next(dataiter)
    concatenated = torch.cat((x0,x1),0)
    
    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.cpu().data.numpy()[0][0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d758cdd1e890> in <module>()
# ----> 1 folder_dataset_test = dset.ImageFolder(root=Config.testing_dir)
#       2 siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
#       3                                         transform=transforms.Compose([transforms.Scale((100,100)),
#       4                                                                       transforms.ToTensor()
#       5                                                                       ])
#
# NameError: name 'dset' is not defined
